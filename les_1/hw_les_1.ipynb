# %% [markdown]
# ### Задание 1

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.array([[5,10],
            [7,12],
            [11.3,5],
            [25,30]])

# %%
b = 7*a + 2*a
b
# Out:
# array([[ 45. ,  90. ],
#        [ 63. , 108. ],
#        [101.7,  45. ],
#        [225. , 270. ]])

# %% [markdown]
# ### Задание 4

# %% [markdown]
# Задание (в программе):m
#  Постройте на одном графике две кривые y(x) для функции двух переменных y(k,x)=cos(k∙x), взяв для одной кривой значение k=1, а для другой – любое другое k, не равное 1.

# %%
k=1
k_2=3
x=np.linspace(0,10,200)
plt.plot(x, np.cos(k*x))
plt.plot(x, np.cos(k_2*x))

# %%
a = np.array([[8,-7,-4],
            [-12,-37,-59],
            [-41,-1,-26]])

# %%
b=1/200*a
b
# Out:
# array([[ 0.04 , -0.035, -0.02 ],
#        [-0.06 , -0.185, -0.295],
#        [-0.205, -0.005, -0.13 ]])

# %%
c=np.array([[7],
            [3],
            [12]])

# %%
i= b*c
i
# Out:
# array([[ 0.28 , -0.245, -0.14 ],
#        [-0.18 , -0.555, -0.885],
#        [-2.46 , -0.06 , -1.56 ]])
